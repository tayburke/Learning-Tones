# %% [markdown]
# ## Imports

# %%
# all the necessary imports to run the file
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/
import sys

# installing packages that may not be installed on user's computer
# !{sys.executable} -m pip install sounddevice
# !{sys.executable} -m pip install librosa
# !{sys.executable} -m pip install tensorflow
# !{sys.executable} -m pip install keras

import os
import sounddevice as sd
from scipy.io.wavfile import write
import librosa
from pathlib import Path
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences
import time
import shutil
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') #don't display warnings about librosa falling back onto another package
# Out:
# Requirement already satisfied: sounddevice in /opt/anaconda3/lib/python3.7/site-packages (0.3.15)
# Requirement already satisfied: CFFI>=1.0 in /opt/anaconda3/lib/python3.7/site-packages (from sounddevice) (1.14.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.7/site-packages (from CFFI>=1.0->sounddevice) (2.20)
# Requirement already satisfied: librosa in /opt/anaconda3/lib/python3.7/site-packages (0.7.2)
# Requirement already satisfied: audioread>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (2.1.8)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: six>=1.3 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (1.14.0)
# Requirement already satisfied: soundfile>=0.9.0 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: joblib>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (0.14.1)
# Requirement already satisfied: numba>=0.43.0 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (0.49.0)
# Requirement already satisfied: decorator>=3.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (1.18.1)
# Requirement already satisfied: resampy>=0.2.2 in /opt/anaconda3/lib/python3.7/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/lib/python3.7/site-packages (from soundfile>=0.9.0->librosa) (1.14.0)
# Requirement already satisfied: llvmlite<=0.33.0.dev0,>=0.31.0.dev0 in /opt/anaconda3/lib/python3.7/site-packages (from numba>=0.43.0->librosa) (0.32.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from numba>=0.43.0->librosa) (46.1.3.post20200330)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.7/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.20)
# Requirement already satisfied: tensorflow in /opt/anaconda3/lib/python3.7/site-packages (2.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.29.0)
# Requirement already satisfied: astunparse==1.6.3 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: gast==0.3.3 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.18.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (46.1.3.post20200330)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.6.0.post3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.14.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.1.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.7/site-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.2.0)
# Requirement already satisfied: keras in /opt/anaconda3/lib/python3.7/site-packages (2.3.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/anaconda3/lib/python3.7/site-packages (from keras) (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /opt/anaconda3/lib/python3.7/site-packages (from keras) (1.18.1)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.7/site-packages (from keras) (1.14.0)
# Requirement already satisfied: h5py in /opt/anaconda3/lib/python3.7/site-packages (from keras) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/anaconda3/lib/python3.7/site-packages (from keras) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /opt/anaconda3/lib/python3.7/site-packages (from keras) (1.4.1)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.7/site-packages (from keras) (5.3.1)
# /opt/anaconda3/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /opt/anaconda3/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# Using TensorFlow backend.

# %% [markdown]
# ## Initial Data Processing

# %% [markdown]
# <pr> The section does NOT need to be run when using the program. It was used to initially load in all the audio files, take 20 mfccs, transform the data, and save the data as numpy arrays for future use. <pr>

# %%
X = list()
y = list()
max_padding = 0

data = Path('.gitignore/tone_perfect_mp3').iterdir()

for item in data:
    if item.is_file():
        filename = item.name.split("_") #"{}{}_{}V{}_MP3.mp3".format(mword, tone, gender, personID)
        y.append(int(filename[0][-1])) 
        
        #transform all of the data to mfccs (Mel Frequency Cepstral Coefficients)
        #https://medium.com/prathena/the-dummys-guide-to-mfcc-aceab2450fd
        
        audio, sampling_rate = librosa.load(item)
        mfcc = librosa.feature.mfcc(y=audio, sr=sampling_rate, n_mfcc=20) 
        X.append(mfcc)
        total_audio_time = len(mfcc[0])
        if total_audio_time > max_padding: max_padding = total_audio_time

#padding each audio file's mcffs with zero so all audio files are considered the same duration 
for i in range(len(X)):
    X[i] = pad_sequences(X[i], padding='post', maxlen = max_padding)

#transforming from (file, coefficients, time) to (file, time, coefficients)
X = np.asarray(X, dtype=np.float32)
X = np.transpose(X, (0, 2, 1))

# %%
#save the numpy arrays to significatly cut down on run time 
np.save('mcffs.npy', X)
np.save('labels.npy', y)

# %% [markdown]
# # The Model

# %% [markdown]
# ## Loading in Data

# %%
X = np.load('mcffs.npy')
y = np.load('labels.npy')

# Split data into 60% training, 10% testing, and 10% validation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state=42)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size = .25)

# %% [markdown]
# ## Data Visualization

# %%
import librosa.display
from itertools import combinations 
  
tones = np.unique(y)

for tone in tones:
    X_tone = X[np.where(y == tone)]
    librosa.display.specshow(np.mean(X_tone, axis=0), x_axis='time')
    plt.colorbar()
    plt.title('Spectogram of average MFCC for tone {}'.format(tone))
    plt.tight_layout()
    plt.show()

# show in a grid plot
# tone_combinations = combinations(tones, 2) 
# for tone1, tone2 in list(tone_combinations):

# %%
# Websites I referred:  
# https://towardsdatascience.com/recurrent-neural-networks-by-example-in-python-ffd204f99470
# https://adventuresinmachinelearning.com/keras-lstm-tutorial/

from keras.utils import to_categorical
import random

# most of code below was found in the second source above with moderate changes
# since we did not cover RNN or LSTM in class
class KerasBatchGenerator(object):

    def __init__(self, X, y, timesteps, batch_size, num_tones):
        self.X = X
        self.y = to_categorical(y-1, num_classes = num_tones)
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.num_tones = num_tones

    def generate(self):
        # shuffle all the indices so that every epoch's batch sampling is different
        randomized_indices = np.array([*range(0,len(self.X))])
        random.shuffle(randomized_indices)
        
        num_inter = 0
        while True:
            
            start_index = num_inter * self.batch_size
            batch_indices = randomized_indices[start_index: self.batch_size + start_index]
            X_batch = self.X[batch_indices]
            y_batch = self.y[batch_indices]
            
            yield X_batch, y_batch
            
            num_inter += 1
            if len(self.X) <= (num_inter * self.batch_size):
                num_inter = 0
                random.shuffle(randomized_indices)

# %%
from keras.models import Sequential 
from keras.layers import LSTM, Dense, TimeDistributed, Activation
from keras.callbacks import ModelCheckpoint


batch_size = 24 
timesteps = len(X_train[0])
hidden_size = 500
num_epochs = 50
tones = 4

X_train_generator = KerasBatchGenerator(X_train, y_train, timesteps, batch_size, tones)                                       
X_validation_generator = KerasBatchGenerator(X_validation, y_validation, timesteps, batch_size, tones)

model = Sequential()
model.add(LSTM(hidden_size, batch_input_shape=(None, timesteps, 20)))
model.add(Dropout(0.5))
model.add(Dense(tones))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

checkpointer = ModelCheckpoint(filepath='model_checkpoints/model-{epoch:02d}.hdf5', verbose=1)
model.fit_generator(X_train_generator.generate(), 
                    len(X_train)//(batch_size*timesteps), 
                    num_epochs, 
                    validation_data = X_validation_generator.generate(), 
                    validation_steps = len(X_validation)//(batch_size*timesteps), 
                    callbacks=[checkpointer])
print(model.summary())
# Out:
# Epoch 1/50
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
#
# (24, 60, 20)
# (24, 4)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)(24, 60, 20)
# (24, 4)
#
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)(24, 60, 20)
# (24, 4)
#
# (24, 60, 20)
# (24, 4)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 1s - loss: 1.3900 - categorical_accuracy: 0.3750(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.3423 - categorical_accuracy: 0.2917(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.3064 - categorical_accuracy: 0.3472(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 343ms/step - loss: 1.2808 - categorical_accuracy: 0.4167 - val_loss: 1.1392 - val_categorical_accuracy: 0.5417
#
# Epoch 00001: saving model to model_checkpoints/model-01.hdf5
# Epoch 2/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2350 - categorical_accuracy: 0.4583(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.1386 - categorical_accuracy: 0.5000(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.2541 - categorical_accuracy: 0.4306(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 260ms/step - loss: 1.2765 - categorical_accuracy: 0.4271 - val_loss: 1.3226 - val_categorical_accuracy: 0.4167
#
# Epoch 00002: saving model to model_checkpoints/model-02.hdf5
# Epoch 3/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.4363 - categorical_accuracy: 0.2917(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.4683 - categorical_accuracy: 0.3125(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.3519 - categorical_accuracy: 0.4028(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 254ms/step - loss: 1.2786 - categorical_accuracy: 0.4375 - val_loss: 1.0914 - val_categorical_accuracy: 0.6250
#
# Epoch 00003: saving model to model_checkpoints/model-03.hdf5
# Epoch 4/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2502 - categorical_accuracy: 0.5000(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.2953 - categorical_accuracy: 0.4167(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.3130 - categorical_accuracy: 0.4167(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 270ms/step - loss: 1.3164 - categorical_accuracy: 0.3646 - val_loss: 1.2004 - val_categorical_accuracy: 0.5000
#
# Epoch 00004: saving model to model_checkpoints/model-04.hdf5
# Epoch 5/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3170 - categorical_accuracy: 0.3750(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.2735 - categorical_accuracy: 0.3542(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.2513 - categorical_accuracy: 0.4028(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 256ms/step - loss: 1.2135 - categorical_accuracy: 0.4167 - val_loss: 1.1195 - val_categorical_accuracy: 0.5000
#
# Epoch 00005: saving model to model_checkpoints/model-05.hdf5
# Epoch 6/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2102 - categorical_accuracy: 0.3750(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.1523 - categorical_accuracy: 0.5208(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.1748 - categorical_accuracy: 0.4861(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 277ms/step - loss: 1.1708 - categorical_accuracy: 0.4792 - val_loss: 1.1298 - val_categorical_accuracy: 0.4167
#
# Epoch 00006: saving model to model_checkpoints/model-06.hdf5
# Epoch 7/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.1554 - categorical_accuracy: 0.3750(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.0328 - categorical_accuracy: 0.5000(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0528 - categorical_accuracy: 0.4722(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 244ms/step - loss: 1.0144 - categorical_accuracy: 0.5000 - val_loss: 1.1964 - val_categorical_accuracy: 0.4583
#
# Epoch 00007: saving model to model_checkpoints/model-07.hdf5
# Epoch 8/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.2517 - categorical_accuracy: 0.4583(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.2680 - categorical_accuracy: 0.4583(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.2781 - categorical_accuracy: 0.4444(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 240ms/step - loss: 1.3338 - categorical_accuracy: 0.4167 - val_loss: 1.0668 - val_categorical_accuracy: 0.6250
#
# Epoch 00008: saving model to model_checkpoints/model-08.hdf5
# Epoch 9/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8475 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.0400 - categorical_accuracy: 0.5000(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0904 - categorical_accuracy: 0.4444(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 232ms/step - loss: 1.0667 - categorical_accuracy: 0.4792 - val_loss: 0.8518 - val_categorical_accuracy: 0.6250
#
# Epoch 00009: saving model to model_checkpoints/model-09.hdf5
# Epoch 10/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9888 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.9387 - categorical_accuracy: 0.6875(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9333 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 229ms/step - loss: 0.9232 - categorical_accuracy: 0.6354 - val_loss: 0.7156 - val_categorical_accuracy: 0.7500
#
# Epoch 00010: saving model to model_checkpoints/model-10.hdf5
# Epoch 11/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0990 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.9235 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9281 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 228ms/step - loss: 0.9123 - categorical_accuracy: 0.6042 - val_loss: 0.9233 - val_categorical_accuracy: 0.5417
#
# Epoch 00011: saving model to model_checkpoints/model-11.hdf5
# Epoch 12/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6274 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7296 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7916 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 224ms/step - loss: 0.8655 - categorical_accuracy: 0.6042 - val_loss: 0.6836 - val_categorical_accuracy: 0.7500
#
# Epoch 00012: saving model to model_checkpoints/model-12.hdf5
# Epoch 13/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7197 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7397 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6166 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 232ms/step - loss: 0.7609 - categorical_accuracy: 0.7500 - val_loss: 1.2462 - val_categorical_accuracy: 0.5000
# Epoch 00013: saving model to model_checkpoints/model-13.hdf5
# Epoch 14/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9405 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.8514 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8545 - categorical_accuracy: 0.6944(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 226ms/step - loss: 0.7855 - categorical_accuracy: 0.7188 - val_loss: 1.0179 - val_categorical_accuracy: 0.5417
#
# Epoch 00014: saving model to model_checkpoints/model-14.hdf5
# Epoch 15/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0238 - categorical_accuracy: 0.5417(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.0722 - categorical_accuracy: 0.4583(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0663 - categorical_accuracy: 0.5139(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 230ms/step - loss: 0.9830 - categorical_accuracy: 0.5625 - val_loss: 0.8321 - val_categorical_accuracy: 0.7500
#
# Epoch 00015: saving model to model_checkpoints/model-15.hdf5
# Epoch 16/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7615 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.9352 - categorical_accuracy: 0.6458(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9042 - categorical_accuracy: 0.6528(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 218ms/step - loss: 0.9070 - categorical_accuracy: 0.6458 - val_loss: 1.1367 - val_categorical_accuracy: 0.4167
#
# Epoch 00016: saving model to model_checkpoints/model-16.hdf5
# Epoch 17/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9674 - categorical_accuracy: 0.5417(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 1.0531 - categorical_accuracy: 0.4792(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9915 - categorical_accuracy: 0.5417(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 208ms/step - loss: 0.9664 - categorical_accuracy: 0.5625 - val_loss: 0.8096 - val_categorical_accuracy: 0.7083
#
# Epoch 00017: saving model to model_checkpoints/model-17.hdf5
# Epoch 18/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7374 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7141 - categorical_accuracy: 0.7292(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6909 - categorical_accuracy: 0.7778(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 212ms/step - loss: 0.6839 - categorical_accuracy: 0.7604 - val_loss: 0.6153 - val_categorical_accuracy: 0.7083
#
# Epoch 00018: saving model to model_checkpoints/model-18.hdf5
# Epoch 19/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6602 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7752 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7136 - categorical_accuracy: 0.7361(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 221ms/step - loss: 0.7347 - categorical_accuracy: 0.7083 - val_loss: 0.8986 - val_categorical_accuracy: 0.5417
#
# Epoch 00019: saving model to model_checkpoints/model-19.hdf5
# Epoch 20/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5845 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5552 - categorical_accuracy: 0.7708(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5596 - categorical_accuracy: 0.8056(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 250ms/step - loss: 0.5691 - categorical_accuracy: 0.7917 - val_loss: 0.6492 - val_categorical_accuracy: 0.7500
#
# Epoch 00020: saving model to model_checkpoints/model-20.hdf5
# Epoch 21/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9810 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.9290 - categorical_accuracy: 0.6875(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9328 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 238ms/step - loss: 0.8713 - categorical_accuracy: 0.6875 - val_loss: 0.5923 - val_categorical_accuracy: 0.7500
#
# Epoch 00021: saving model to model_checkpoints/model-21.hdf5
# Epoch 22/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6532 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6259 - categorical_accuracy: 0.7292(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7108 - categorical_accuracy: 0.6806(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 213ms/step - loss: 0.7240 - categorical_accuracy: 0.6667 - val_loss: 1.2686 - val_categorical_accuracy: 0.6250
#
# Epoch 00022: saving model to model_checkpoints/model-22.hdf5
# Epoch 23/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8771 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6625 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6938 - categorical_accuracy: 0.7222(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 222ms/step - loss: 0.7584 - categorical_accuracy: 0.6875 - val_loss: 0.5416 - val_categorical_accuracy: 0.7917
#
# Epoch 00023: saving model to model_checkpoints/model-23.hdf5
# Epoch 24/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5233 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6700 - categorical_accuracy: 0.6875(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6634 - categorical_accuracy: 0.6944(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 218ms/step - loss: 0.6965 - categorical_accuracy: 0.7083 - val_loss: 0.6093 - val_categorical_accuracy: 0.7917
#
# Epoch 00024: saving model to model_checkpoints/model-24.hdf5
# Epoch 25/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7919 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6527 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6433 - categorical_accuracy: 0.7639(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 219ms/step - loss: 0.6207 - categorical_accuracy: 0.7708 - val_loss: 0.4207 - val_categorical_accuracy: 0.8750
#
# Epoch 00025: saving model to model_checkpoints/model-25.hdf5
# Epoch 26/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7162 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6479 - categorical_accuracy: 0.7292(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6238 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 225ms/step - loss: 0.6664 - categorical_accuracy: 0.7292 - val_loss: 0.7185 - val_categorical_accuracy: 0.7917
#
# Epoch 00026: saving model to model_checkpoints/model-26.hdf5
# Epoch 27/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5964 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7280 - categorical_accuracy: 0.6875(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6699 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 211ms/step - loss: 0.6623 - categorical_accuracy: 0.7292 - val_loss: 0.7449 - val_categorical_accuracy: 0.6667
#
# Epoch 00027: saving model to model_checkpoints/model-27.hdf5
# Epoch 28/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5604 - categorical_accuracy: 0.8333(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6287 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5334 - categorical_accuracy: 0.8194(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 211ms/step - loss: 0.5711 - categorical_accuracy: 0.8021 - val_loss: 0.6432 - val_categorical_accuracy: 0.6667
#
# Epoch 00028: saving model to model_checkpoints/model-28.hdf5
# Epoch 29/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6014 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6437 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7052 - categorical_accuracy: 0.7778(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 258ms/step - loss: 0.7079 - categorical_accuracy: 0.7396 - val_loss: 0.6810 - val_categorical_accuracy: 0.7083
#
# Epoch 00029: saving model to model_checkpoints/model-29.hdf5
# Epoch 30/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6993 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7406 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7957 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 248ms/step - loss: 0.7892 - categorical_accuracy: 0.6042 - val_loss: 0.5938 - val_categorical_accuracy: 0.7083
#
# Epoch 00030: saving model to model_checkpoints/model-30.hdf5
# Epoch 31/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8101 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7083 - categorical_accuracy: 0.7292(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6141 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 223ms/step - loss: 0.5541 - categorical_accuracy: 0.7812 - val_loss: 1.2113 - val_categorical_accuracy: 0.5417
#
# Epoch 00031: saving model to model_checkpoints/model-31.hdf5
# Epoch 32/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6213 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5915 - categorical_accuracy: 0.7292(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5846 - categorical_accuracy: 0.7361(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 224ms/step - loss: 0.5937 - categorical_accuracy: 0.7500 - val_loss: 0.9383 - val_categorical_accuracy: 0.7500
#
# Epoch 00032: saving model to model_checkpoints/model-32.hdf5
# Epoch 33/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9715 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7314 - categorical_accuracy: 0.7292(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6910 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 236ms/step - loss: 0.7758 - categorical_accuracy: 0.6979 - val_loss: 0.5472 - val_categorical_accuracy: 0.7917
#
# Epoch 00033: saving model to model_checkpoints/model-33.hdf5
# Epoch 34/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4777 - categorical_accuracy: 0.8750(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5919 - categorical_accuracy: 0.7708(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5488 - categorical_accuracy: 0.7778(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 244ms/step - loss: 0.6555 - categorical_accuracy: 0.7500 - val_loss: 0.4425 - val_categorical_accuracy: 0.8333
#
# Epoch 00034: saving model to model_checkpoints/model-34.hdf5
# Epoch 35/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7506 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6920 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6920 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 248ms/step - loss: 0.7109 - categorical_accuracy: 0.7083 - val_loss: 0.6476 - val_categorical_accuracy: 0.7083
#
# Epoch 00035: saving model to model_checkpoints/model-35.hdf5
# Epoch 36/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7367 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6136 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5882 - categorical_accuracy: 0.7639(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 259ms/step - loss: 0.6384 - categorical_accuracy: 0.7188 - val_loss: 0.7144 - val_categorical_accuracy: 0.7083
#
# Epoch 00036: saving model to model_checkpoints/model-36.hdf5
# Epoch 37/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4595 - categorical_accuracy: 0.8333(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.4854 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6110 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 257ms/step - loss: 0.6147 - categorical_accuracy: 0.7708 - val_loss: 0.7185 - val_categorical_accuracy: 0.6250
#
# Epoch 00037: saving model to model_checkpoints/model-37.hdf5
# Epoch 38/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7568 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6866 - categorical_accuracy: 0.6458(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7091 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 245ms/step - loss: 0.6862 - categorical_accuracy: 0.6979 - val_loss: 0.6109 - val_categorical_accuracy: 0.8333
#
# Epoch 00038: saving model to model_checkpoints/model-38.hdf5
# Epoch 39/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6284 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5853 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6653 - categorical_accuracy: 0.6944(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 259ms/step - loss: 0.7199 - categorical_accuracy: 0.6562 - val_loss: 0.3149 - val_categorical_accuracy: 0.8750
#
# Epoch 00039: saving model to model_checkpoints/model-39.hdf5
# Epoch 40/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6556 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5110 - categorical_accuracy: 0.8333(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6224 - categorical_accuracy: 0.7778(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 254ms/step - loss: 0.5804 - categorical_accuracy: 0.7917 - val_loss: 0.5321 - val_categorical_accuracy: 0.7500
# Epoch 00040: saving model to model_checkpoints/model-40.hdf5
# Epoch 41/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6837 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6238 - categorical_accuracy: 0.6458(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7448 - categorical_accuracy: 0.6111(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 273ms/step - loss: 0.7444 - categorical_accuracy: 0.6354 - val_loss: 0.4841 - val_categorical_accuracy: 0.8333
#
# Epoch 00041: saving model to model_checkpoints/model-41.hdf5
# Epoch 42/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4913 - categorical_accuracy: 0.8750(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5666 - categorical_accuracy: 0.8542(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5556 - categorical_accuracy: 0.8333(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 251ms/step - loss: 0.5646 - categorical_accuracy: 0.8333 - val_loss: 0.8568 - val_categorical_accuracy: 0.6667
#
# Epoch 00042: saving model to model_checkpoints/model-42.hdf5
# Epoch 43/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5190 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5727 - categorical_accuracy: 0.7083(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6397 - categorical_accuracy: 0.6944(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 215ms/step - loss: 0.6234 - categorical_accuracy: 0.7083 - val_loss: 0.3321 - val_categorical_accuracy: 0.9167
#
# Epoch 00043: saving model to model_checkpoints/model-43.hdf5
# Epoch 44/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9290 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.7499 - categorical_accuracy: 0.7292(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6821 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 210ms/step - loss: 0.6920 - categorical_accuracy: 0.7500 - val_loss: 0.6838 - val_categorical_accuracy: 0.6250
#
# Epoch 00044: saving model to model_checkpoints/model-44.hdf5
# Epoch 45/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.9160 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.8572 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7537 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 212ms/step - loss: 0.7982 - categorical_accuracy: 0.6667 - val_loss: 0.5065 - val_categorical_accuracy: 0.7917
#
# Epoch 00045: saving model to model_checkpoints/model-45.hdf5
# Epoch 46/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6762 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.6098 - categorical_accuracy: 0.7708(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5968 - categorical_accuracy: 0.7778(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 209ms/step - loss: 0.5917 - categorical_accuracy: 0.7604 - val_loss: 0.8870 - val_categorical_accuracy: 0.6250
#
# Epoch 00046: saving model to model_checkpoints/model-46.hdf5
# Epoch 47/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8102 - categorical_accuracy: 0.6667(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.8564 - categorical_accuracy: 0.6250(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.7269 - categorical_accuracy: 0.6806(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 213ms/step - loss: 0.6164 - categorical_accuracy: 0.7396 - val_loss: 0.5373 - val_categorical_accuracy: 0.7083
#
# Epoch 00047: saving model to model_checkpoints/model-47.hdf5
# Epoch 48/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4035 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.4734 - categorical_accuracy: 0.7917(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.4883 - categorical_accuracy: 0.8333(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 208ms/step - loss: 0.4562 - categorical_accuracy: 0.8438 - val_loss: 0.6818 - val_categorical_accuracy: 0.7917
#
# Epoch 00048: saving model to model_checkpoints/model-48.hdf5
# Epoch 49/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5608 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5115 - categorical_accuracy: 0.7500(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5069 - categorical_accuracy: 0.7639(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 213ms/step - loss: 0.4571 - categorical_accuracy: 0.7812 - val_loss: 0.7380 - val_categorical_accuracy: 0.7917
#
# Epoch 00049: saving model to model_checkpoints/model-49.hdf5
# Epoch 50/50
# (24, 60, 20)
# (24, 4)
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4599 - categorical_accuracy: 0.8333(24, 60, 20)
# (24, 4)
# 2/4 [==============>...............] - ETA: 0s - loss: 0.5357 - categorical_accuracy: 0.7708(24, 60, 20)
# (24, 4)
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5213 - categorical_accuracy: 0.7639(24, 60, 20)
# (24, 4)
# (24, 60, 20)
# (24, 4)
# 4/4 [==============================] - 1s 250ms/step - loss: 0.5645 - categorical_accuracy: 0.7500 - val_loss: 0.6008 - val_categorical_accuracy: 0.7500
#
# Epoch 00050: saving model to model_checkpoints/model-50.hdf5
# Model: "sequential_58"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_57 (LSTM)               (None, 500)               1042000
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 4)                 2004
# _________________________________________________________________
# activation_44 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 1,044,004
# Trainable params: 1,044,004
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# plot the training accuracy over time for the chosen hyperparameters
# https://www.codesofinterest.com/2017/03/graph-model-training-history-keras.html


prediction = model.predict(X_test)
accuracy = np.sum(np.argmax(prediction, axis = 1) == y_test - 1)/len(y_test)
print(accuracy)
# Out:
# 0.7576219512195121

# %% [markdown]
# # User Interface

# %% [markdown]
# ## Create folder to hold user audio
# <p> Run the following cell to remove previous user audio and make the folder to hold all user input audio. <p>

# %%
#initializing folder to hold user audio
user_audio_directory = ("user_audio")
try:
    shutil.rmtree(user_audio_directory)
    os.makedirs(user_audio_directory)
    print("Removed data and recreated folder", user_audio_directory)
except(FileNotFoundError):
    os.makedirs(user_audio_directory)
    print("Created folder {}".format(user_audio_directory))

# %% [markdown]
# ## Record user's voice

# %% [markdown]
# <pr> Following cell records a user's voice. Users are encouraged to only record monosyllabic words in order to practice tonalities. An unclear recording will result in a low<pr>

# %%
frame_rate = 44100
duration = 1.5 #seconds

print("Recording in...")
pause = 3

while pause > 0:
    print("{}".format(pause))
    pause -= 1
    time.sleep(1)
print("RECORDING")

recording = sd.rec(int(duration * frame_rate), samplerate = frame_rate, channels = 1)
recording_num = len(os.listdir('user_audio/')) + 1
recording_name = 'user_audio/sample_audio_{}.mp3'.format(recording_num)
sd.wait()
write(recording_name, frame_rate, recording)

print("Finished")

# %% [markdown]
# ## Play back and plot the user recording
# <pr> User can play back and see a visualization of their latest recording as many times as they like. <pr>

# %%
try: 
    audio, sampling_rate = librosa.load(recording_name)
    
    #plot
    timeline = np.arange(0, len(audio))/sampling_rate
    fig = plt.figure()
    plt.plot(timeline, audio)
    plt.xlabel("Time (s)", fontsize=18)
    plt.ylabel("Amplitude", fontsize=16)
               
    #play back
    sd.play(audio, sampling_rate)
    sd.wait()
    sd.stop()
except(FileNotFoundError):
    print("Please go back and run the previous two cells")

# %% [markdown]
# ## Delete all user recordings

# %%
try:
    shutil.rmtree(user_audio_directory)
    print("Successfully removed user data")
except(FileNotFoundError):
    print("User data already deleted".format(user_audio_directory))

# %% [markdown]
# # Classify user recording

# %%
#pad user recording
#make an mcff
#
